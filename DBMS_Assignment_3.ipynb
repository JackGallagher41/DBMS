# %% [markdown]
# <a href="https://colab.research.google.com/github/JackGallagher41/DBMS/blob/main/DBMS_Assignment_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Jack Gallagher**

# %% [markdown]
# Assignment 3

# %% [markdown]
# October 10, 2023

# %% [markdown]
# ## **Constraints:**

# %% [markdown]
# -Products name constraint: Printer, Ethernet Adapter, Desktop, Hard Drive, Laptop, Router, Network Card, Super Drive, Monitor
#
# -Products category constraint: Peripheral, Networking, Computer
#
# -Sell price constraint: between 0 and 100,000
#
# -Sell quantity_available constraint: between 0 and 1,000
#
# -Orders shipping_method constraint: UPS, FedEx, USPS
#
# -Orders shipping_cost constraint: between 0 and 500

# %% [markdown]
# ![Constraints Set.png](data:image/png;base64,...)

# %% [markdown]
# ## **1. List names and sellers of products that are no longer available (quantity=0)**

# %% [markdown]
# ![Question 1.png](data:image/png;base64,...)

# %% [markdown]
# Used Inner Join in order to get the names and merchants (sellers). Used where to check quantity was 0.

# %% [markdown]
# ## **2. List names and descriptions of products that are not sold.**

# %% [markdown]
# ![q2.png](data:image/png;base64,...)

# %% [markdown]
# does a left join to getting product name and description where sell.pid is null. (Whenever a sell.pid doesnt show up for a products.pid)

# %% [markdown]
# ## **3. How many customers bought SATA drives but not any routers?**

# %% [markdown]
# ![q3 attempt 2.png](data:image/png;base64,...)

# %% [markdown]
# Use a chain of join statements to connect customers to products. Check where SATA Drives are and then check to make sure no router was bought. 0 people bought

# %% [markdown]
# ## **4. HP has a 20% sale on all its Networking products.**

# %% [markdown]
# ![q4.png](data:image/png;base64,...)

# %% [markdown]
# joined to get product and merchant for category and merchant name in which we pulled the product name and the new discounted price.

# %% [markdown]
# ## **5. What did Uriel Whitney order from Acer? (make sure to at least retrieve product names and prices).**

# %% [markdown]
# ![q5.png](data:image/png;base64,...)

# %% [markdown]
# I used a wide connected join connecting merchant to customer.
# From select we get price and product for everything where name is uriel whitney and merchant is acer

# %% [markdown]
# ## **6. List the annual total sales for each company (sort the results along the company and the year attributes).**

# %% [markdown]
# ![q6.png](data:image/png;base64,...)

# %% [markdown]
# using contain we are able to find the amount of oid or pid in order to figure out how much of a product was sold. We then multiply the total count by the price grouping it by year and company listing the annual total sales

# %% [markdown]
# ## **7. Which company had the highest annual revenue and in what year?**

# %% [markdown]
# ![q7.png](data:image/png;base64,...)

# %% [markdown]
# Simply add a limit of 1 and order by descending annual total sales to get the highest.

# %% [markdown]
# ## **8. On average, what was the cheapest shipping method used ever?**

# %% [markdown]
# ![q8.png](data:image/png;base64,...)

# %% [markdown]
# Takes the average of each shipping method and sorts them by cheapest to most expensive. USPS is cheapest

# %% [markdown]
# ## **9. What is the best sold ($) category for each company?**

# %% [markdown]
# ![q9.png](data:image/png;base64,...)

# %% [markdown]
# We are able to find each sales for product which when sorting by descending order, we are able to conclude the Peripheral is the highest seller for every company

# %% [markdown]
# ## **10. For each company find out which customers have spent the most and the least amounts.**

# %% [markdown]
# ![q10 p.1.png](data:image/png;base64,...)

# %% [markdown]
# ![q10 p.2.png](data:image/png;base64,...)

# %% [markdown]
# when taking count oid and multiplying it by the price we are able to find the max and min of each company as well as their total spent and which customer it is
